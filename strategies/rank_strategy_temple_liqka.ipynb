# %%
from vpny_qmlt.trader.base import BacktestingMode
import warnings
import rank_strategy_liqka_out as strategy
from importlib import reload
from vpny_qmlt.gateway.backtesting import engine
from vpny_qmlt.trader.optimize import OptimizationSetting
from vpny_qmlt.trader.setting import SETTINGS
from vpny_qmlt.trader.constant import Interval

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import logging
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
SETTINGS["log.level"] = logging.INFO

warnings.filterwarnings('ignore')

engine = engine.BacktestingEngine()

#                     )
engine.set_parameters(
    interval=Interval.MINUTE,  # 周期，分为tick，分钟，小时
    # start=20220101,
    # end=20210712,  # start,end是根据tranding_day来的, 输入int如20210511
    slippage_tick=0,
    capital=20000000,
    vt_symbols=["rb99.SHFE"],  # ["rb99.SHFE", ],
    rates=[1 / 10000],
    source_dir="Y:\\DataBase_RQ_files\\",  # "Y:\\DataBase_RQ_files\\",
    margin_rates=[0.13]
)
engine.add_strategy(strategy.Test01, "test", ['rb99.SHFE'], {
    # 'shift_rtn': 200,
    "test": {'sample_size': 30000,
             "bins" :20},
    "liqka": {"TRS": 0.03, "delta_t": 0.003, "min_thre": 0.5},
    "self.min":1,
    "risky_window" :10
})

# %%
engine.run()
engine.show_backtesting_result(save=True)
# engine.get_show_engine().show_sub_daily_result("rb99.SHFE")
# engine.get_show_engine().show_sub_daily_result("i99.DCE")
# engine.show_backtesting_plot()
# Out:
# 2023-05-09 15:13:27.449075	开始加载历史数据
# 2023-05-09 15:13:31.523791	回测开始,Bar数量=99.6万行
# b'2010-01-04 09:01:00.000001\t\xe6\x8c\x87\xe6\xa0\x87\xe5\x88\x9d\xe5\xa7\x8b'
# b'2010-01-04 09:01:00.000002\t\xe4\xbf\xa1\xe5\x8f\xb7\xe5\x88\x9d\xe5\xa7\x8b\xe5\x8c\x96'
# 2023-05-09 15:13:33.978807	[rb99]数据为0,请检查数据的开始和结束时间
# b'2010-01-04 09:01:00.000005\t\xe7\xad\x96\xe7\x95\xa5\xe5\x88\x9d\xe5\xa7\x8b'
# b'2010-01-04 09:01:00.000006\t\xe7\xad\x96\xe7\x95\xa5\xe5\x88\x9d\xe5\xa7\x8b\xe5\x8c\x96'
# b'2010-01-04 09:01:00.000007\t\xe7\xad\x96\xe7\x95\xa5\xe5\x90\xaf\xe5\x8a\xa8'
# b'2010-01-04 09:01:00.000008\t\xe7\xad\x96\xe7\x95\xa5\xe5\x90\xaf\xe5\x8a\xa8'
#
# b'2023-05-05 14:59:00.000001\tterminate strategy,test'
# b'2023-05-05 14:59:00.000002\t\xe6\x8c\x87\xe6\xa0\x87\xe9\x87\x8a\xe6\x94\xbe'
# b'2023-05-05 14:59:00.000003\t\xe7\xad\x96\xe7\x95\xa5\xe5\x81\x9c\xe6\xad\xa2'
# b'2023-05-05 14:59:00.000004\t\xe7\xad\x96\xe7\x95\xa5\xe9\x87\x8a\xe6\x94\xbe'
# 回测结果不满足置信水平。交易笔数：实际(886) > 胜率要求最小值(736.0); 交易天数：实际(3429) < 夏普要求最小值(10467.1)
#                             Values   Indicators_2                   Values_2
# Indicators
# 第一笔交易时间        2011-06-24 13:51:00       最后一笔交易时间        2022-09-02 22:44:00
# 总交易天数                         3429          总交易笔数                        886
# 起始资金                    20,000,000           期末资金                 20,130,100
# 最大占用资金                     510,896       最大占用资金说明        最大持仓市值的30% + 最大回撤资金
# 日均交易笔数                        0.26         交易笔数说明               一开一平算一笔,不论手数
# -------------        -------------  -------------              -------------
# 年化收益率                       1.8 %          年化收益说明       不考虑复利:总收益率*250/总交易天数
# 夏普率（日）                        0.02         夏普率（年）                       0.25
# 波动率（年）                       7.198          收益回撤比                        2.0
# -------------        -------------  -------------              -------------
# 总收益                        130,101           总收益率                    25.47 %
# 总交易手数                          886         日均交易手数                        0.3
# 总手续费                         6,562        每笔交易手续费                       7.41
# 每手收益                         146.8          每手收益率                     0.03 %
# 最高收益                       180,421          最高收益率                    35.31 %
# -------------        -------------  -------------              -------------
# 日均收益率                        0.01%
# 日胜率FIFO                       1.3%       日盈亏比FIFO                        1.5
# 日均盈利FIFO                   10989.2       日均亏损FIFO                    -7437.0
# 每笔胜率FIFO                     42.8%        每笔胜率HIS                      45.4%
# 盈利均值FIFO                    1032.1        盈利均值HIS                      929.7
# 亏损均值FIFO                    -514.9        亏损均值HIS                     -503.4
# 盈亏比FIFO                        2.0         盈亏比HIS                        1.8
# 最大调整期(笔)                       275       最大调整期(天)                       2450
# 最高亏损                       -34,868          最高亏损率                    -6.82 %
# -------------        -------------  -------------              -------------
# 回撤本金比                     -12.45 %        回撤本金比说明              最大回撤净值/最大占用资金
# 最大回撤(比例)                   -11.4 %     最大回撤(比例)说明  (最大占用资金+收益)曲线中从前高下跌的最大跌幅
# 最大回撤(净值)                   -63,586       最大回撤(说明)    (最大占用资金+收益)曲线中从前高下跌的最大值
# 最大回撤(净值)天数                    2446     最大回撤(比例)天数                       2446
# 最大回撤(净值)笔数                     199     最大回撤(比例)笔数                        199
# 最大回撤恢复（净值）               76 笔  4 天     最大回撤恢复（比例）                  76 笔  4 天

# %%
# import numpy as np


# def low(data: np.ndarray, n: int) -> np.ndarray:
#     """
#     计算n期的low与当前值差多少期/总期数
#     """
#     def rolling_window(a, window):
#         shape = a.shape[:-1] + (a.shape[-1] - window + 1, window)
#         strides = a.strides + (a.strides[-1],)
#         return np.lib.stride_tricks.as_strided(a, shape=shape, strides=strides)

#     def find_low_index(x):
#         return np.argmin(x)

#     rolling_data = rolling_window(data, n)
#     low_index = np.apply_along_axis(find_low_index, 1, rolling_data)
#     return (n - low_index) / n


# # Example usage
# data = np.array([1, 2, 3, 4, 5, 4, 3, 2, 1])
# n = 3
# def low(data: pd.Series, n):
#     """
#     计算n期的low与当前值差多少期/总期数
#     """
#     low_index = data.rolling(n).apply(lambda x: np.argmin(x))
#     return (n - low_index) / n
# ds=pd.Series(data)
# r2 =low(ds, n)
# #对比low1和low的运行速度
# %timeit low1(data, n)
# %timeit low(ds, n)

# %%
# engine.show_backtesting_result(save=True)               # 把总体回测结果保存到本地
order_details = engine.se.get_order_detail(save=True)   # 获取订单详情保存到本地
pnl_details = engine.se.get_pnl_fifo_detail(save=True)  # 获取逐笔盈亏详情 保存到本地

# %%
pnl_details = pd.read_csv("pnl_fifo_detail.csv")
pnl_details
# Out:
#      Unnamed: 0 symbol  pricetick  entry_order_id  entry_trade_id  \
# 0             1   rb99        1.0               1               1
# 1             2   rb99        1.0               2               2
# 2             3   rb99        1.0               3               3
# 3             4   rb99        1.0               4               4
# 4             5   rb99        1.0               5               5
# ..          ...    ...        ...             ...             ...
# 881         882   rb99        1.0            1025             973
# 882         883   rb99        1.0            1026             974
# 883         884   rb99        1.0            1027             975
# 884         885   rb99        1.0            1028             976
# 885         886   rb99        1.0            1029             977
#
#     entry_direction entry_offset  entry_order_p       entry_order_dt  \
# 0                 空            开         4703.0  2011-06-20 09:36:00
# 1                 空            开         4701.0  2011-06-20 09:37:00
# 2                 空            开         4703.0  2011-06-20 09:40:00
# 3                 空            开         4701.0  2011-06-20 10:49:00
# 4                 空            开         4704.0  2011-06-20 10:50:00
# ..              ...          ...            ...                  ...
# 881               空            开         3666.0  2022-09-02 13:57:00
# 882               空            开         3665.0  2022-09-02 13:58:00
# 883               空            开         3662.0  2022-09-02 13:59:00
# 884               空            开         3663.0  2022-09-02 14:00:00
# 885               空            开         3666.0  2022-09-02 14:01:00
#
#      entry_order_v  ...  exit_trade_id exit_direction  exit_offset  \
# 0                1  ...             32              多            平
# 1                1  ...             32              多            平
# 2                1  ...             32              多            平
# 3                1  ...             32              多            平
# 4                1  ...             32              多            平
# ..             ...  ...            ...            ...          ...
# 881              1  ...            978              多            平
# 882              1  ...            978              多            平
# 883              1  ...            978              多            平
# 884              1  ...            978              多            平
# 885              1  ...            978              多            平
#
#      exit_order_p        exit_order_dt exit_order_v  exit_trade_p  \
# 0          4747.0  2011-06-24 13:51:00           31     4746.6284
# 1          4747.0  2011-06-24 13:51:00           31     4746.6284
# 2          4747.0  2011-06-24 13:51:00           31     4746.6284
# 3          4747.0  2011-06-24 13:51:00           31     4746.6284
# 4          4747.0  2011-06-24 13:51:00           31     4746.6284
# ..            ...                  ...          ...           ...
# 881        3709.0  2022-09-02 22:44:00           31     3709.0000
# 882        3709.0  2022-09-02 22:44:00           31     3709.0000
# 883        3709.0  2022-09-02 22:44:00           31     3709.0000
# 884        3709.0  2022-09-02 22:44:00           31     3709.0000
# 885        3709.0  2022-09-02 22:44:00           31     3709.0000
#
#            exit_trade_dt  closed_volume   close_pnl
# 0    2011-06-24 13:51:00             -1 -445.733628
# 1    2011-06-24 13:51:00             -1 -465.731628
# 2    2011-06-24 13:51:00             -1 -445.733628
# 3    2011-06-24 13:51:00             -1 -463.736828
# 4    2011-06-24 13:51:00             -1 -425.990603
# ..                   ...            ...         ...
# 881  2022-09-02 22:44:00             -1 -430.861651
# 882  2022-09-02 22:44:00             -1 -447.374000
# 883  2022-09-02 22:44:00             -1 -470.997637
# 884  2022-09-02 22:44:00             -1 -457.622975
# 885  2022-09-02 22:44:00             -1 -437.375000
#
# [886 rows x 23 columns]

# %%
a = {1:1,2:2,3:3}
a.pop(1)
a
# Out:
# {2: 2, 3: 3}

# %%
d ={"a":1,"b":2,    "c":3}

for k, v in d.items():
    d.pop(k)
d
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 3
#       1 d ={"a":1,"b":2,    "c":3}
# ----> 3 for k, v in d.items():
#       4     d.pop(k)
#       5 d
#
# RuntimeError: dictionary changed size during iteration

# %%
d = {}

for k, v in d.copy().items():
    d.pop(k)

# %%
from vpny_qmlt.trader.optimize import OptimizationSetting
op_settings = {}

op_setting = OptimizationSetting()
sf18_parameter = OptimizationSetting()
liqka_parameter = OptimizationSetting()


op_setting.add_parameter("minbar", 5)

sf18_parameter.add_parameter("p", 6, 10, 1)
sf18_parameter.add_parameter("p_short", 40, 41, 1)
op_setting.add_optimizationsetting("sf18_parameter", sf18_parameter)

liqka_parameter.add_parameter("TRS", 0.03, 0.04, 0.01)
liqka_parameter.add_parameter("delta_t", 0.02)
liqka_parameter.add_parameter("min_thre", 0.3)
op_setting.add_optimizationsetting("liqka", liqka_parameter)

op_settings["sf18"] = op_setting
op_settings["sf18_i99"] = op_setting

a,b =engine.run_optimization(op_settings, target_name="total profit rate", output=True)

# %%
c, d = engine.run_ga_optimization(
    op_settings, target_name="total profit rate", output=True)

# %%
# 把 engine.optimize_result 保存成为pkl文件
import pickle
with open("optimize_result.pkl", "wb") as f:
    pickle.dump(engine.optimize_result, f)
with open ("ga_optimize_result.pkl", "wb") as f:
    pickle.dump(engine.ga_optimize_result, f)

# %%
# engine.get_show_engine().calculate_daily_result()

# %% [markdown]
# ![image.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
